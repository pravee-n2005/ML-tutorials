# %% [markdown]
# <a href="https://colab.research.google.com/github/pravee-n2005/ML-tutorials/blob/main/Linear%20Regression%20Multiple%20Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from word2number import w2n

# %%
# %pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=b4b6274ed235fd240a29d76a9dbd4919e9aac1e91dd33089fee73a570712a414
#   Stored in directory: /root/.cache/pip/wheels/5b/79/fb/d25928e599c7e11fe4e00d32048cd74933f34a74c633d2aea6
# Successfully built word2number
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML Practices/hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.experience = df.experience.fillna('zero')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
###We are ging to change the experience for m word to number
df.experience = df.experience.apply(w2n.word_to_num)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
import math
median_test_score = math.floor(df['test_score(out of 10)'].mean())
median_test_score
# Out:
# 7

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(median_test_score)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']], df['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])

# %%
reg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93747.79628651])
